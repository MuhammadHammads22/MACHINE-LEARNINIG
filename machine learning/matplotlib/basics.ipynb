# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# Basic Graph

# %%
x=[0,1,2,3]
y=[0,4,5,6]
plt.figure(figsize=(5,4),dpi=300)
plt.plot(x,y,color='grey',linewidth=3,marker="*",linestyle="--",markersize=15,markeredgecolor="red")

plt.title("our firts graph",fontdict={'fontname':'comic sans ms','fontsize':35})
plt.xlabel('X Axis',fontdict={'fontname':'comic sans ms','fontsize':35})
plt.ylabel('Y Axis',fontdict={'fontname':'comic sans ms','fontsize':35})
# plt.xticks([1,2,3,4])
# plt.yticks([1,3,5,7])


x2=[0,1,2,3,4,5,6,7.5]

plt.plot(x2[:6],np.square(x2[:6]),"r^--")
plt.plot(x2[5:],np.square(x2[5:]),color="blue",linestyle="-.",marker='.')
# plt.savefig("firstsgraph.png",dpi=300)
plt.legend()

plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Bar Chart

# %%
label=['p1','p2','p3']
weights=[45,63,99]
bar1=plt.bar(label,weights)
bar1[0].set_hatch('o')
bar1[1].set_hatch('/')
bar1[2].set_hatch('*')

# %% [markdown]
# REAL WORLD EXAMPLES

# %%
gas=pd.read_csv("gas_prices.csv")
# table=pd.DataFrame(gas)
# print(pd.DataFrame.from_dict(table))
# print(gas.iloc[0])
countries=gas.columns
countries=countries[2::2]
for country in countries:
    print(country)
    plt.plot(gas.Year,gas[country],label=country,marker=".")
# plt.plot(gas.Year,gas.USA,label="united states")
# plt.plot(gas.Year,gas.Canada,label="canada")
# # for country in countries:
#     # plt.plot(gas.Year,)
plt.xlabel("time period")
plt.title("Increase in gas prices over time in (USD)",fontdict={"fontsize":20,"fontweight":"bold"})
plt.ylabel("price")
plt.xticks(gas.Year[::3])
plt.savefig("Gas price graph.png",dpi=300)
plt.legend()


plt.show()
# Out:
# Canada
# Germany
# Japan
# South Korea
# USA

# %%
gas=pd.read_csv("gas_prices.csv")
table=pd.DataFrame(gas)
country=[f"USA({gas.Year[5]})",f"Canada({gas.Year[5]})",f"Australia({gas.Year[5]})"]
price=[gas.USA[5],gas.Canada[5],gas.Australia[5]]
plt.ylabel("Price in USD")
plt.bar(country,price)
# Out:
# <BarContainer object of 3 artists>
